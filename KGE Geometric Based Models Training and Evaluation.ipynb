# %%
# !git clone -b dev_hoc-nt https://github.com/NguyenThaiHoc1/CustomKnowledgeGraphEmbedding.git
# Out:
# Cloning into 'CustomKnowledgeGraphEmbedding'...
# remote: Enumerating objects: 1005, done.
# remote: Counting objects: 100% (918/918), done.
# remote: Compressing objects: 100% (400/400), done.
# remote: Total 1005 (delta 519), reused 866 (delta 497), pack-reused 87
# Receiving objects: 100% (1005/1005), 32.36 MiB | 14.20 MiB/s, done.
# Resolving deltas: 100% (544/544), done.
# Updating files: 100% (73/73), done.

# %% [markdown]
# # Dataset - GCS
#
# ## WN18rr
#
#
# *   Train: gs://kds-89e05a9b37d4cef78ffea9b8dc0cb64c1cbc90193250fdc60e8f0f21/train/
# *   Test : gs://kds-89e05a9b37d4cef78ffea9b8dc0cb64c1cbc90193250fdc60e8f0f21/test/
#
# *   Infor: gs://kds-89e05a9b37d4cef78ffea9b8dc0cb64c1cbc90193250fdc60e8f0f21/info.txt
#
# hidden dim = 1000
# ## FB_15K
# *   gs://hien7613storage2/datasets/KGE/fb15k/train
# *   gs://hien7613storage2/datasets/KGE/fb15k/valid
# *   gs://hien7613storage2/datasets/KGE/fb15k/test
# *   nenitity: 14951 - nrelation: 1345
#
# ## OGB
#
#
#
#
# *   gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train
# *   gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/valid
# *   gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/test
#
# *   nenitity: 2500604 - nrelation: 535
#
# *   16109180

# %% [markdown]
# # Run Code

# %% [markdown]
# ## DistMulti score function

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://hien7613storage2/datasets/KGE/fb15k/train" \
--test_path "gs://hien7613storage2/datasets/KGE/fb15k/valid" \
-bz 256 \
-sf "DistMult" \
--nentity 14951 \
--nrelation 1345 \
--hidden_dim 256 \
--gamma 24.0 \
--epochs 80000 \
--steps_per_epoch  1000 \
--multiple_files \
--validation_steps 70 \
--validation_freq 4
# Out:
# 2023-10-17 14:43:42.224218: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-17 14:43:44.226907: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-10-17 14:43:46.884216: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:450] Started server with target: grpc://localhost:39450
# Number of accelerators:  8
# ...

# %% [markdown]
# ## ComplEx score function

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://hien7613storage2/datasets/KGE/win18rr/train" \
--test_path "gs://hien7613storage2/datasets/KGE/win18rr/valid" \
-bz 256 \
-sf "ComplEx" \
--nentity 40943 \
--nrelation 11 \
--hidden_dim 256 \
--gamma 24.0 \
--epochs 2000 \
--steps_per_epoch 1000 \
-dr -de --multiple_files \
--validation_steps 200 \
--validation_freq 300
# Out:
# 2023-11-09 02:27:33.633827: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-09 02:27:36.092152: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-11-09 02:27:39.189801: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:450] Started server with target: grpc://localhost:40513
# Number of accelerators:  8
# ...

# %% [markdown]
# # Pure

# %% [markdown]
# ## TransD

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://hien7613storage2/datasets/KGE/fb15k/train/" \
--test_path "gs://hien7613storage2/datasets/KGE/fb15k/valid" \
-bz 1024 \
-sf "TransD" \
--nentity 14951 \
--nrelation 1345 \
--hidden_dim 128 \
--gamma 24.0 \
--epochs 100 \
--steps_per_epoch 1000 \
-de -dr --multiple_files \
--validation_freq 6
# Out:
# 2023-10-17 08:35:39.462801: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Number of accelerators:  8
# 2023-10-17 08:35:48.495108: W tensorflow/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# Head - Train List files:
#  ['gs://hien7613storage2/datasets/KGE/fb15k/train/fb15k-0-head.tfrec']
# Tail - Train List files:
#  ['gs://hien7613storage2/datasets/KGE/fb15k/train/fb15k-0-tail.tfrec']
# ...
# Head - Test List files:
#  ['gs://hien7613storage2/datasets/KGE/fb15k/valid/fb15k-0-head.tfrec']
# Tail - Test List files:
#  ['gs://hien7613storage2/datasets/KGE/fb15k/valid/fb15k-0-tail.tfrec']
# ...
# 1. Data loading complete.
# 2. Score function check complete.
# ...

# %%
import tensorflow as tf
import time
from tqdm import tqdm
from collections import namedtuple

# %% [markdown]
# ## TransE

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train/" \
--test_path "gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/test" \
-bz 1024 \
-sf "TransE" \
--nentity 2500604 \
--nrelation 535 \
--hidden_dim 128 \
--gamma 24.0 \
--epochs 100 \
--steps_per_epoch 1000 \
--multiple_files
# Out:
# 2023-10-17 04:54:51.094373: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Number of accelerators:  8
# 2023-10-17 04:58:33.083656: W tensorflow/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# Head - Train List files:
# ...

# %% [markdown]
# ## TranSparse

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run.py \
-ip "gs://kds-89e05a9b37d4cef78ffea9b8dc0cb64c1cbc90193250fdc60e8f0f21/train/" \
-bz 128 \
-sf "TranSparse" \
--nentity 40943 \
--nrelation 11 \
--hidden_dim 1000 \
--gamma 24.0 \
--epochs 1 \
--steps_per_epoch 1000 \
--multiple_files
# Out:
# 2023-09-25 02:55:55.882222: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-25 02:55:59.039513: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-25 02:56:01.373637: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:450] Started server with target: grpc://localhost:36010
# Number of accelerators:  8
# ...

# %% [markdown]
# # Rotate

# %% [markdown]
# ## RotatE

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://hien7613storage2/datasets/KGE/fb15k/train/" \
--test_path "gs://hien7613storage2/datasets/KGE/fb15k/valid" \
-bz 256 \
-sf "RotatE" \
--nentity 14951 \
--nrelation 1345 \
--hidden_dim 256 \
--gamma 12.0 \
--epochs 2000 \
--steps_per_epoch 1000 \
-de --multiple_files\
--validation_steps 200 \
--validation_freq 300
# Out:
# Streaming output truncated to the last 5000 lines.
#  999/1000 [============================>.] - ETA: 0s - loss: 0.1350WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.1350
# Epoch 155/2000
#  999/1000 [============================>.] - ETA: 0s - loss: 0.1350WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# 1000/1000 [==============================] - 27s 27ms/step - loss: 0.1350
# Epoch 156/2000
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1351WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.1351
# ...

# %%
import numpy as np
import tensorflow as tf

epsilon = 2.
hidden_dim=256
embedding_range = tf.Variable([(23. + epsilon) / hidden_dim], trainable=False, dtype=tf.float32)
pi = tf.constant(np.pi, dtype=tf.float32)
gamma = 24.
def compute_score(head, tail, relation):
    re_head, im_head = tf.split(head, num_or_size_splits=2, axis=2)
    re_tail, im_tail = tf.split(tail, num_or_size_splits=2, axis=2)
    phase_relation = relation / (embedding_range / pi)
    re_relation = tf.cos(phase_relation)
    im_relation = tf.sin(phase_relation)

    re_score_0 = re_relation * re_tail + im_relation * im_tail - re_head
    im_score_0 = re_relation * im_tail - im_relation * re_tail - im_head
    re_score_1 = re_head * re_relation - im_head * im_relation - re_tail
    im_score_1 = re_head * im_relation + im_head * re_relation - im_tail

    score_0 = tf.norm(tf.stack([re_score_0, im_score_0], axis=0), axis=2)
    score_1 = tf.norm(tf.stack([re_score_1, im_score_1], axis=0), axis=2)

    choice = tf.cond(tf.equal(mode, 0), lambda: 1.0, lambda: 0.0)

    score = score_0 * choice + score_1 * (1 - choice)
    score = gamma - tf.reduce_sum(score, axis=2)
    return score

mode = 1
head = tf.random.uniform(shape=[1,1,hidden_dim])
tail = tf.random.uniform(shape=[1,256,hidden_dim])
relation = tf.random.uniform(shape=[1,1,hidden_dim//2])
compute_score(head, tail, relation)
# Out:
# <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[-1548.235 ],
#        [-1514.7295]], dtype=float32)>

# %%
# %cd ..
# Out:
# /content

# %% [markdown]
# ## RotPro

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train/" \
--test_path "gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/valid" \
-bz 512 \
-sf "RotPro" \
--nentity 40943 \
--nrelation 11 \
--hidden_dim 1000 \
--gamma 24.0 \
--epochs 100 \
--steps_per_epoch 3147 \
-dr --multiple_files
# Out:
# 2023-10-17 04:52:23.280713: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ^C

# %%
# !gsutil  mv  gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/* \
  gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train/
# Out:
# Copying gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/ogbl-0-head.tfrec [Content-Type=application/octet-stream]...
# Removing gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/ogbl-0-head.tfrec...
# Copying gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/ogbl-0-tail.tfrec [Content-Type=application/octet-stream]...
# Removing gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/ogbl-0-tail.tfrec...
# Copying gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/ogbl-1-head.tfrec [Content-Type=application/octet-stream]...
# Removing gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/ogbl-1-head.tfrec...
#
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# ...

# %%
# !gsutil  mv  gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/6/*.tfrec \
  gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/
# Out:
# Copying gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/6/ogbl-6-head.tfrec [Content-Type=application/octet-stream]...
# Removing gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/6/ogbl-6-head.tfrec...
# Copying gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/6/ogbl-6-tail.tfrec [Content-Type=application/octet-stream]...
# Removing gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train2/6/ogbl-6-tail.tfrec...
#
# Operation completed over 2 objects/2.8 GiB.

# %% [markdown]
# ## RotateCT

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/train/" \
--test_path "gs://hien7613storage2/datasets/KGE/ogbl-wikikg2/valid" \
-bz 16 \
-sf "RotateCT" \
--nentity 2500604 \
--nrelation 535 \
--hidden_dim 256 \
--gamma 24.0 \
--epochs 2000 \
--steps_per_epoch 1000 \
-de -tr --multiple_files \
--validation_steps 200 \
--validation_freq 300
# Out:
# 2023-11-13 02:10:49.177036: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-13 02:10:50.497645: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-11-13 02:10:52.891871: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:450] Started server with target: grpc://localhost:40986
# Number of accelerators:  8
# ...

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://hien7613storage2/datasets/KGE/win18rr/train" \
--test_path "gs://hien7613storage2/datasets/KGE/win18rr/valid" \
-bz 256 \
-sf "RotateCT" \
--nentity 40943 \
--nrelation 11 \
--hidden_dim 256 \
--gamma 24.0 \
--epochs 2000 \
--steps_per_epoch 1000 \
-de -tr --multiple_files \
--validation_steps 100 \
--validation_freq 300
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Epoch 410/2000
#  999/1000 [============================>.] - ETA: 0s - loss: 1.2460e-04WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# 1000/1000 [==============================] - 28s 28ms/step - loss: 1.2463e-04
# Epoch 411/2000
#  998/1000 [============================>.] - ETA: 0s - loss: 1.2411e-04WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# 1000/1000 [==============================] - 27s 27ms/step - loss: 1.2411e-04
# Epoch 412/2000
#  999/1000 [============================>.] - ETA: 0s - loss: 1.2341e-04WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# WARNING:tensorflow:Can save best model only with val_MRR available, skipping.
# ...

# %%
mode=val
model=yolov8n.yaml
data=coco8.yaml
epochs=100
patience=50
batch=16
imgsz=640
save=True
save_period=-1
cache=False
device=None
workers=0
project=None
name=val8
exist_ok=False
pretrained=True
optimizer=auto
verbose=True
seed=0
deterministic=True
single_cls=False
rect=True
cos_lr=False
close_mosaic=10
resume=False
amp=True
fraction=1.0
profile=False
freeze=None
overlap_mask=True
mask_ratio=4
dropout=0.0
val=True
split=val
save_json=False
save_hybrid=False
conf=None
iou=0.7
max_det=300
half=False
dnn=False
plots=True
source=None
show=False
save_txt=False
save_conf=False
save_crop=False
show_labels=True
show_conf=True
vid_stride=1
stream_buffer=False
line_width=None
visualize=False
augment=False
agnostic_nms=False
classes=None
retina_masks=False
boxes=True
format=torchscript
keras=False
optimize=False
int8=False
dynamic=False
simplify=False
opset=None
workspace=4
nms=False
lr0=0.01
lrf=0.01
momentum=0.937
weight_decay=0.0005
warmup_epochs=3.0
warmup_momentum=0.8
warmup_bias_lr=0.1
box=7.5
cls=0.5
dfl=1.5
pose=12.0
kobj=1.0
label_smoothing=0.0
nbs=64
hsv_h=0.015
hsv_s=0.7
hsv_v=0.4
degrees=0.0
translate=0.1
scale=0.5
shear=0.0
perspective=0.0
flipud=0.0
fliplr=0.5
mosaic=0.0
mixup=0.0
copy_paste=0.0
cfg=None
tracker=botsort.yaml

# %% [markdown]
# # Additional

# %% [markdown]
# ## STransE

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://hien7613storage2/datasets/KGE/win18rr/train" \
--test_path "gs://hien7613storage2/datasets/KGE/win18rr/valid" \
-bz 256 \
-sf "STransE" \
--nentity 40943 \
--nrelation 11 \
--hidden_dim 256 \
--gamma 24.0 \
--epochs 2000 \
--steps_per_epoch 1000 \
--multiple_files \
--validation_steps 200 \
--validation_freq 300
# Out:
# 2023-11-08 19:00:31.009229: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Number of accelerators:  8
# 2023-11-08 19:00:44.833426: W tensorflow/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# Head - Train List files:
# ...

# %% [markdown]
# ## InterHT

# %%
# !pwd
# Out:
# /content

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://hien7613storage2/datasets/KGE/fb15k/train/" \
--test_path "gs://hien7613storage2/datasets/KGE/fb15k/valid" \
-bz 512 \
-sf "InterHT" \
--nentity 14951 \
--nrelation 1345 \
--hidden_dim 256 \
--gamma 24.0 \
--epochs 2000 \
--steps_per_epoch 1000 \
-de --multiple_files \
--validation_steps 200 \
--validation_freq 300
# Out:
# 2023-10-18 03:18:09.045035: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Number of accelerators:  8
# 2023-10-18 03:18:22.340005: W tensorflow/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# Head - Train List files:
#  ['gs://hien7613storage2/datasets/KGE/fb15k/train/fb15k-0-head.tfrec']
# Tail - Train List files:
#  ['gs://hien7613storage2/datasets/KGE/fb15k/train/fb15k-0-tail.tfrec']
# ...
# Head - Test List files:
#  ['gs://hien7613storage2/datasets/KGE/fb15k/valid/fb15k-0-head.tfrec']
# Tail - Test List files:
#  ['gs://hien7613storage2/datasets/KGE/fb15k/valid/fb15k-0-tail.tfrec']
# ...
# 1. Data loading complete.
# 2. Score function check complete.
# ...

# %%
import tensorflow as tf
tf.linalg.normalize(tf.random.uniform([2,5,7]), ord=2, axis=-1)[1]
# Out:
# <tf.Tensor: shape=(2, 5, 1), dtype=float32, numpy=
# array([[[1.0489208],
#         [1.355539 ],
#         [1.636688 ],
#         [1.547427 ],
#         [1.419114 ]],
#
#        [[1.6269791],
#         [1.4836274],
#         [1.61119  ],
#         [1.4174398],
#         [1.6624641]]], dtype=float32)>

# %% [markdown]
# ## TripleRE

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://hien7613storage2/datasets/KGE/fb15k/train" \
--test_path "gs://hien7613storage2/datasets/KGE/fb15k/valid" \
-bz 512 \
-sf "TripleRE" \
--nentity 14951 \
--nrelation 1345 \
--hidden_dim 256 \
--gamma 24.0 \
--epochs 80000 \
--steps_per_epoch  1000 \
-tr --multiple_files \
--validation_steps 100 \
--validation_freq 20
# Out:
# 2023-10-17 19:39:38.373721: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-17 19:39:40.792611: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-10-17 19:39:44.697428: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:450] Started server with target: grpc://localhost:53729
# Number of accelerators:  8
# ...

# %%
# %cd /content/CustomKnowledgeGraphEmbedding
/content/CustomKnowledgeGraphEmbedding/tensorflow_codes
# Out:
# /content/CustomKnowledgeGraphEmbedding
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-7aaf85199fe7> in <cell line: 2>()
#       1 get_ipython().run_line_magic('cd', '/content/CustomKnowledgeGraphEmbedding')
# ----> 2 content/CustomKnowledgeGraphEmbedding/tensorflow_codes()
#
# NameError: name 'content' is not defined

# %% [markdown]
# ## TranS

# %%
93003//512*50
# Out:
# 9050

# %%
# %cd ..
# Out:
# /content

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
-ip "gs://kds-a28b7df29920000a74750ef31c2c27bf95e1ce9adbae6add979a3f5c/train/" \
--test_path "gs://kds-744d5458792b2ed2e65a382ee3c536c467ef9098d35083120f5ac03a/valid/" \
-bz 256 \
-sf "TranS" \
--nentity 40943 \
--nrelation 11 \
--hidden_dim 256 \
--gamma 24.0 \
--epochs 80000 \
--steps_per_epoch  1000 \
-de -tr --multiple_files \
--validation_steps 70 \
--validation_freq 4
# Out:
# 2023-10-04 09:25:33.004140: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Number of accelerators:  8
# 2023-10-04 09:25:43.926073: W tensorflow/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# Head - Train List files:
# ...

# %% [markdown]
# # zz

# %%
import tensorflow as tf

def getRank(y_true, y_pred):
  rankings = tf.where(tf.equal(y_pred, tf.expand_dims(y_true, axis=-1)))
  true_rankings = rankings[:, -1] + 1
  # ranking = tf.where(y_pred == y_true[:, tf.newaxis])[:,1] + 1
  ranking = tf.cast(true_rankings, tf.float32)
  return ranking

class MeanReciprocalRank(tf.keras.metrics.Metric):
    def __init__(self, name='mrr', **kwargs):
        super(MeanReciprocalRank, self).__init__(name=name, **kwargs)
        self.mrr = self.add_weight(name='mrr', initializer='zeros')
        self.total_samples = self.add_weight(name='total_samples', initializer='zeros')
    def update_state(self, y_true, y_pred, sample_weight=None):
        ranking = getRank(y_true, y_pred)
        self.mrr.assign_add(tf.reduce_sum(tf.constant(1.) / ranking))
        self.total_samples.assign_add(tf.cast(tf.shape(y_true)[0], tf.float32))
    def result(self):
        return self.mrr / self.total_samples
    def reset_state(self):
        self.mrr.assign(0)
        self.total_samples.assign(0)

class MeanRank(tf.keras.metrics.Metric):
    def __init__(self, name='mr', **kwargs):
        super(MeanRank, self).__init__(name=name, **kwargs)
        self.mr = self.add_weight(name='mr', initializer='zeros')
        self.total_samples = self.add_weight(name='total_samples', initializer='zeros')
    def update_state(self, y_true, y_pred, sample_weight=None):
        ranking = getRank(y_true, y_pred)
        self.mr.assign_add(tf.reduce_sum(ranking))
        self.total_samples.assign_add(tf.cast(tf.shape(y_true)[0], tf.float32))
    def result(self):
        return self.mr / self.total_samples
    def reset_state(self):
        self.mr.assign(0)
        self.total_samples.assign(0)

class HitsAt1(tf.keras.metrics.Metric):
    def __init__(self, name='hits_at_1', **kwargs):
        super(HitsAt1, self).__init__(name=name, **kwargs)
        self.hits_at_1 = self.add_weight(name='hits_at_1', initializer='zeros')
        self.total_samples = self.add_weight(name='total_samples', initializer='zeros')
    def update_state(self, y_true, y_pred, sample_weight=None):
        ranking = getRank(y_true, y_pred)
        self.hits_at_1.assign_add(tf.reduce_sum(tf.where(ranking <= 1, 1.0, 0.0)))
        self.total_samples.assign_add(tf.cast(tf.shape(y_true)[0], tf.float32))
    def result(self):
        return self.hits_at_1 / self.total_samples
    def reset_state(self):
        self.hits_at_1.assign(0)
        self.total_samples.assign(0)

class HitsAt10(tf.keras.metrics.Metric):
    def __init__(self, name='hits_at_10', **kwargs):
        super(HitsAt10, self).__init__(name=name, **kwargs)
        self.hits_at_10 = self.add_weight(name='hits_at_10', initializer='zeros')
        self.total_samples = self.add_weight(name='total_samples', initializer='zeros')
    def update_state(self, y_true, y_pred, sample_weight=None):
        ranking = getRank(y_true, y_pred)
        self.hits_at_10.assign_add(tf.reduce_sum(tf.where(ranking <= 10, 1.0, 0.0)))
        self.total_samples.assign_add(tf.cast(tf.shape(y_true)[0], tf.float32))
    def result(self):
        return self.hits_at_10 / self.total_samples
    def reset_state(self):
        self.hits_at_10.assign(0)
        self.total_samples.assign(0)


class Trainer(tf.keras.Model):
    def __init__(self, strategy, model):
        super().__init__()
        self.model = model
        self.strategy = strategy
        self.metric_loss = tf.keras.metrics.Mean('loss', dtype=tf.float32)

    def train_step(self, inputs):
        positive_sample, negative_sample, subsampling_weight, mode = inputs
        with tf.GradientTape() as tape:
            negative_score = self.model.negative_call(((positive_sample, negative_sample), mode[0]), training=True)
            negative_score = tf.reduce_sum(
                tf.nn.softmax(negative_score * 1, axis=1) * tf.math.log_sigmoid(-negative_score), axis=1,
                keepdims=True
            )
            positive_score = self.model.positive_call(((positive_sample, negative_sample), 3), training=True)
            positive_score = tf.math.log_sigmoid(positive_score)
            positive_sample_loss = -tf.reduce_sum(subsampling_weight * positive_score) / tf.reduce_sum(
                subsampling_weight)
            negative_sample_loss = -tf.reduce_sum(subsampling_weight * negative_score) / tf.reduce_sum(
                subsampling_weight)
            loss = (positive_sample_loss + negative_sample_loss) / 2

        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))

        self.metric_loss.update_state(loss * self.strategy.num_replicas_in_sync)
        return {'loss': self.metric_loss.result()}

    def test_step(self, data):
          positive_sample, negative_sample, filter_bias, mode = data
          mode = mode[0]
          positive_arg = tf.cond(tf.equal(mode, 0), lambda: positive_sample[:, 0], lambda: positive_sample[:, 2])
          positive_arg = tf.cast(positive_arg, dtype=tf.int32)

          score = self.model.negative_call(((positive_sample, negative_sample), mode[0]), training=False) + filter_bias
          argsort = tf.argsort(score, axis=1, direction='DESCENDING')
          self.compiled_metrics.update_state(positive_arg, argsort)
          return {m.name: m.result() for m in self.metrics}

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import tensorflow as tf
import os
import argparse
from architecture.model import TFKGEModel
# from supervisor import Trainer
from model_fit import Trainer, MeanReciprocalRank, MeanRank,HitsAt1,HitsAt10


def check_device():
    try:  # detect TPUs
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()  # TPU detection
        strategy = tf.distribute.TPUStrategy(tpu)
    except ValueError:  # detect GPUs
        # strategy = tf.distribute.MirroredStrategy()  # for GPU or multi-GPU machines
        strategy = tf.distribute.get_strategy()  # default strategy that works on CPU and single GPU
        # strategy = tf.distribute.experimental.MultiWorkerMirroredStrategy() # for clusters of multi-GPU machines
    print("Number of accelerators: ", strategy.num_replicas_in_sync)
    return strategy


def args_parser():
    parser = argparse.ArgumentParser(description="Training ...")
    parser.add_argument("-ip", "--input_path", required=True, type=str)
    parser.add_argument("-bz", "--batch_size", required=True, type=int)
    parser.add_argument("--test_path", required=False, type=str)

    parser.add_argument("-sf", "--score_functions", required=True, type=str)
    parser.add_argument("--nentity", required=True, type=int)
    parser.add_argument("--nrelation", required=True, type=int)
    parser.add_argument("--hidden_dim", required=True, type=int)
    parser.add_argument("--gamma", required=True, type=float)
    parser.add_argument("--epochs", required=False, type=int, default=1)
    parser.add_argument("--steps_per_epoch", required=False, type=int, default=1000)
    parser.add_argument("-de", "--double_entity_embedding", action='store_true')
    parser.add_argument("-dr", "--double_relation_embedding", action='store_true')
    parser.add_argument("-tr", "--triple_relation_embedding", action='store_true')
    parser.add_argument("-qr", "--quora_relation_embedding", action='store_true')
    parser.add_argument("--multiple_files", action='store_true')

    args = parser.parse_args()
    return args


def parse_tfrecord_fn(example):
    feature_description = {
        "positive_sample": tf.io.VarLenFeature(tf.int64),
        "negative_sample": tf.io.VarLenFeature(tf.int64),
        "subsampling_weight": tf.io.VarLenFeature(tf.float32),
        "mode": tf.io.VarLenFeature(tf.int64),
    }
    example = tf.io.parse_single_example(example, feature_description)
    example["positive_sample"] = tf.sparse.to_dense(example["positive_sample"])
    example["negative_sample"] = tf.sparse.to_dense(example["negative_sample"])
    example["subsampling_weight"] = tf.sparse.to_dense(example["subsampling_weight"])
    example["mode"] = tf.sparse.to_dense(example["mode"])
    return example


def reshape_function(example, batch_size):
    postive_sample = example["positive_sample"]
    negative_sample = example["negative_sample"]
    subsampling_weight = example["subsampling_weight"]
    mode = example["mode"]

    postive_sample = tf.reshape(postive_sample, [-1])
    negative_sample = tf.reshape(negative_sample, [-1])
    subsampling_weight = tf.reshape(subsampling_weight, [-1])
    mode = tf.reshape(mode, [1])

    return postive_sample, negative_sample, subsampling_weight, mode


def loading_data(head_dataloader_path, tail_dataloader_path, bz, do_training=True):
    try:
        # loading head file
        head_raw_dataset = tf.data.TFRecordDataset(head_dataloader_path)
        head_parsed_dataset = head_raw_dataset.map(parse_tfrecord_fn)
        head_parsed_dataset = head_parsed_dataset.map(
            lambda inputs: reshape_function(inputs, batch_size=args.batch_size))
        head_parsed_dataset = head_parsed_dataset.batch(bz, drop_remainder=True)

        # loading tail file
        tail_raw_dataset = tf.data.TFRecordDataset(tail_dataloader_path)
        tail_parsed_dataset = tail_raw_dataset.map(parse_tfrecord_fn)
        tail_parsed_dataset = tail_parsed_dataset.map(
            lambda inputs: reshape_function(inputs, batch_size=args.batch_size))
        tail_parsed_dataset = tail_parsed_dataset.batch(bz, drop_remainder=True)

        combined_dataset = tf.data.Dataset.sample_from_datasets(
            [head_parsed_dataset, tail_parsed_dataset],
            weights=[0.5, 0.5]
        )

        if do_training:
            combined_dataset = combined_dataset.repeat()

        combined_dataset = combined_dataset.shuffle(buffer_size=bz * 4)
        combined_dataset = combined_dataset.prefetch(buffer_size=bz * 4)
        return combined_dataset
    except Exception as e:
        raise ValueError(f"func loading_data: {e}")


@tf.function
def lrfn(epoch):
    LR_START = 0.00001
    LR_MAX = 0.00005 * strategy.num_replicas_in_sync
    LR_MIN = 0.00001
    LR_RAMPUP_EPOCHS = 5.0
    LR_SUSTAIN_EPOCHS = 0.0
    LR_EXP_DECAY = .8

    if float(epoch) < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * float(epoch) + LR_START
    elif float(epoch) < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        lr = (LR_MAX - LR_MIN) * LR_EXP_DECAY ** (float(epoch) - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS) + LR_MIN
    return lr


def run(strategy, args):
    # reading data ...
    # train
    if not args.multiple_files:
        filenames_head = args.input_path
        filenames_tail = args.input_path
        print(f"Test {args.input_path} is a file")
    else:
        filenames_head = tf.io.gfile.glob(os.path.join(args.input_path, "*-head.tfrec"))
        filenames_tail = tf.io.gfile.glob(os.path.join(args.input_path, "*-tail.tfrec"))
        print(f"Head - Train List files: \n {filenames_head}")
        print(f"Tail - Train List files: \n {filenames_tail}")
    print("====" * 6)

    # test
    if args.test_path is not None:
        test_filenames_head = tf.io.gfile.glob(os.path.join(args.test_path, "*-head.tfrec"))
        test_filenames_tail = tf.io.gfile.glob(os.path.join(args.test_path, "*-tail.tfrec"))
        test_dataloader = loading_data(test_filenames_head, test_filenames_tail, bz=4, do_training=False)
        print(f"Head - Test List files: \n {test_filenames_head}")
        print(f"Tail - Test List files: \n {test_filenames_tail}")
    else:
        test_dataloader = None
    print("====" * 6)

    train_dataloader = loading_data(filenames_head, filenames_tail, bz=args.batch_size, do_training=True)
    print("1. Data loading complete.")

    assert args.score_functions in ["InterHT", "DistMult", "ComplEx",
                                    "RotPro", "RotatE", "RotateCT",
                                    "STransE", "TranS", "TransD", "TransE",
                                    "TripleRE", "TranSparse"], f"{args.score_functions} is not implemented."
    print("2. Score function check complete.")

    with strategy.scope():
        kge_model = TFKGEModel(
            model_name=args.score_functions,
            nentity=args.nentity,
            nrelation=args.nrelation,
            hidden_dim=args.hidden_dim,
            gamma=args.gamma,
            double_entity_embedding=args.double_entity_embedding,
            double_relation_embedding=args.double_relation_embedding,
            triple_relation_embedding=args.triple_relation_embedding,
            quora_relation_embedding=args.quora_relation_embedding
        )

        class LRSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
            def __call__(self, step):
                return lrfn(epoch=step // args.steps_per_epoch)

        # optimizer
        optimizer = tf.keras.optimizers.Adam(learning_rate=LRSchedule())

        # # metrics
        # list_metrics = {
        #     "train_loss": tf.keras.metrics.Mean('training_loss', dtype=tf.float32),
        #     "MRR": tf.keras.metrics.Mean('mrr_evaluate', dtype=tf.float32),
        #     "MR": tf.keras.metrics.Mean('mr_evaluate', dtype=tf.float32),
        #     "HITS_AT_1": tf.keras.metrics.Mean('hit1_evaluate', dtype=tf.float32),
        #     "HITS_AT_3": tf.keras.metrics.Mean('hit3_evaluate', dtype=tf.float32),
        #     "HITS_AT_10": tf.keras.metrics.Mean('hit10_evaluate', dtype=tf.float32)
        # }
        # supervisor
        trainer = Trainer(
            strategy=strategy,
            model=kge_model,
        )
        trainer.compile(optimizer=optimizer, loss=None,
         metrics=[MeanReciprocalRank(), MeanRank(), HitsAt1(), HitsAt10()])

    checkpoint_filepath = f'gs://hien7613storage2/datasets/KGE/ckpt_{kge_model}/'
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_mrr',
        mode='max',
        save_best_only=True)

    print("3. Starting training...")
    trainer.fit(
        train_dataloader,
        steps_per_epoch=1000,
        epochs=150,
        validation_data=test_dataloader,
        validation_freq=4,
        validation_steps=70,
        callbacks=[model_checkpoint_callback]
    )
        # trainer.training(
        #     steps_per_tpu_call=99,
        #     epochs=args.epochs,
        #     steps_per_epoch=args.steps_per_epoch
        # )
    print("4. Training complete.")


if __name__ == '__main__':
    strategy = check_device()
    args = args_parser()
    run(strategy, args)

# %% [markdown]
# # Test

# %%
# %cd /content/CustomKnowledgeGraphEmbedding
# Out:
# /content/CustomKnowledgeGraphEmbedding

# %%
from tensorflow_codes.architecture.model import TFKGEModel
import tensorflow as tf
try:  # detect TPUs
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()  # TPU detection
    strategy = tf.distribute.TPUStrategy(tpu)
except ValueError:  # detect GPUs
    strategy = tf.distribute.get_strategy()  # default strategy that works on CPU and single GPU
print("Number of accelerators: ", strategy.num_replicas_in_sync)
# Out:
# WARNING:tensorflow:TPU system grpc://10.55.190.58:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# Number of accelerators:  8

# %%
# --nentity 40943 \
# --nrelation 11 \
# --hidden_dim 256 \

# %%
# !python ./CustomKnowledgeGraphEmbedding/tensorflow_codes/run_fit.py \
# -ip "gs://hien7613storage2/datasets/KGE/win18rr/train" \
# --test_path "gs://hien7613storage2/datasets/KGE/win18rr/valid" \
# -bz 256 \
# -sf "ComplEx" \
# --nentity 40943 \
# --nrelation 11 \
# --hidden_dim 256 \
# --gamma 24.0 \
# --epochs 2000 \
# --steps_per_epoch 1000 \
# -dr -de --multiple_files \
# --validation_steps 200 \
# --validation_freq 300

# %%
checkpoint_filepath = f'gs://hien7613storage2/datasets/KGE/ckpt_win18rr_RotateCT/'
dataset='win18rr'
score_functions="RotateCT"
nentity=40943
nrelation=11
hidden_dim=256
gamma=24.
double_entity_embedding=True
double_relation_embedding=False
triple_relation_embedding=True
quora_relation_embedding=False


with strategy.scope():
  kge_model = TFKGEModel(
            model_name=score_functions,
            nentity=nentity,
            nrelation=nrelation,
            hidden_dim=hidden_dim,
            gamma=gamma,
            double_entity_embedding=double_entity_embedding,
            double_relation_embedding=double_relation_embedding,
            triple_relation_embedding=triple_relation_embedding,
            quora_relation_embedding=quora_relation_embedding
        )

  optimizer = tf.keras.optimizers.Adam()

  kge_model.compile(
      optimizer=optimizer,
      loss=None
  )
kge_model.built = True
kge_model.load_weights(checkpoint_filepath)

# %%
import os
def parse_tfrecord_fn(example):
    feature_description = {
        "positive_sample": tf.io.VarLenFeature(tf.int64),
        "negative_sample": tf.io.VarLenFeature(tf.int64),
        "subsampling_weight": tf.io.VarLenFeature(tf.float32),
        "mode": tf.io.VarLenFeature(tf.int64),
    }
    example = tf.io.parse_single_example(example, feature_description)
    example["positive_sample"] = tf.sparse.to_dense(example["positive_sample"])
    example["negative_sample"] = tf.sparse.to_dense(example["negative_sample"])
    example["subsampling_weight"] = tf.sparse.to_dense(example["subsampling_weight"])
    example["mode"] = tf.sparse.to_dense(example["mode"])
    return example


def reshape_function(example):
    postive_sample = example["positive_sample"]
    negative_sample = example["negative_sample"]
    subsampling_weight = example["subsampling_weight"]
    mode = example["mode"]

    postive_sample = tf.reshape(postive_sample, [-1])
    negative_sample = tf.reshape(negative_sample, [-1])
    subsampling_weight = tf.reshape(subsampling_weight, [-1])
    mode = tf.reshape(mode, [1])

    return postive_sample, negative_sample, subsampling_weight, mode

def loading_data(head_dataloader_path, tail_dataloader_path, bz, do_training=True):
    try:
        # loading head file
        head_raw_dataset = tf.data.TFRecordDataset(head_dataloader_path)
        head_parsed_dataset = head_raw_dataset.map(parse_tfrecord_fn)
        head_parsed_dataset = head_parsed_dataset.map(
            lambda inputs: reshape_function(inputs))
        head_parsed_dataset = head_parsed_dataset.batch(bz, drop_remainder=True)

        # loading tail file
        tail_raw_dataset = tf.data.TFRecordDataset(tail_dataloader_path)
        tail_parsed_dataset = tail_raw_dataset.map(parse_tfrecord_fn)
        tail_parsed_dataset = tail_parsed_dataset.map(
            lambda inputs: reshape_function(inputs))
        tail_parsed_dataset = tail_parsed_dataset.batch(bz, drop_remainder=True)

        combined_dataset = tf.data.Dataset.sample_from_datasets(
            [head_parsed_dataset, tail_parsed_dataset],
            weights=[0.5, 0.5]
        )

        if do_training:
            combined_dataset = combined_dataset.repeat()

        combined_dataset = combined_dataset.shuffle(buffer_size=bz * 4)
        combined_dataset = combined_dataset.prefetch(buffer_size=bz * 4)
        return combined_dataset
    except Exception as e:
        raise ValueError(f"func loading_data: {e}")
test_path=f"gs://hien7613storage2/datasets/KGE/{dataset}/test/"
test_filenames_head = tf.io.gfile.glob(os.path.join(test_path, "*-head.tfrec"))
test_filenames_tail = tf.io.gfile.glob(os.path.join(test_path, "*-tail.tfrec"))
test_dataloader = loading_data(test_filenames_head, test_filenames_tail, bz=4, do_training=False)
print(f"Head - Test List files: \n {test_filenames_head}")
print(f"Tail - Test List files: \n {test_filenames_tail}")
# Out:
# Head - Test List files:
#  ['gs://hien7613storage2/datasets/KGE/win18rr/test/test-0-head.tfrec', 'gs://hien7613storage2/datasets/KGE/win18rr/test/test-1-head.tfrec', 'gs://hien7613storage2/datasets/KGE/win18rr/test/test-2-head.tfrec', 'gs://hien7613storage2/datasets/KGE/win18rr/test/test-3-head.tfrec', 'gs://hien7613storage2/datasets/KGE/win18rr/test/test-4-head.tfrec', 'gs://hien7613storage2/datasets/KGE/win18rr/test/test-5-head.tfrec', 'gs://hien7613storage2/datasets/KGE/win18rr/test/test-6-head.tfrec', 'gs://hien7613storage2/datasets/KGE/win18rr/test/test-7-head.tfrec', 'gs://hien7613storage2/datasets/KGE/win18rr/test/test-8-head.tfrec', 'gs://hien7613storage2/datasets/KGE/win18rr/test/test-9-head.tfrec']
# Tail - Test List files:
# ...

# %%
kge_model.evaluate(test_dataloader)
# Out:
# 1564/1564 [==============================] - 120s 63ms/step - MRR: 0.3989 - MR: 3620.8773 - HIT@1: 0.1655
# [0.16576087474822998, 3674.259521484375, 0.3999688923358917]
